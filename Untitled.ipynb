# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\renee\\Desktop'

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataframe = pd.read_csv(r"C:\Users\renee\Desktop\Documentos\FACEPREP JAN 2026 - JUNE 2026\PDA\Zomato-data-.csv")
#       2 print(dataframe.head())
#
# ...
